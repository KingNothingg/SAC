# %% [markdown]
# *Тарпанов Даниил М8О-206Б-19*
#
# **Хищник - Жертва**

# %%
var('y1, y2')

t = np.linspace(0,7,71)
y0 = [2, 1]
a,c,d = 3,1,1
pt = plot(0, (x, 0, 3), color='black')

for b in range(4,1,-1):
    params=[a,b,c,d]
    st='a=%d b=%d c=%d d=%d' % tuple(params)
    f = [y1*(a-b*y2),y2*(-c+d*y1)]
    sol = desolve_odeint(f, y0, t, dvars = [y1,y2])
    pt +=line(sol, rgbcolor=(randint(0,256)/256,randint(0,256)/256,randint(0,256)/256))

pt.show(aspect_ratio = 1 )
# Out:
# Graphics object consisting of 4 graphics primitives

# %% [markdown]
# **Бросок под углом к горизонту**

# %%
from scipy.integrate import ode
import numpy as np
import matplotlib.pyplot as plt

ts = [ ]
ys = [ ]

tmax=1.41
alph=np.pi/4
v0=10.0
y0,t0=[0, v0*np.cos(alph), 0, v0*np.sin(alph)], 0

var('y1, y2, y3, y4')

t = np.linspace(0, 7, 300)

k=0.01
g=9.81
f = [y2,
    -k*y2*sqrt(y2**2+y4**2),
    y4,
    -k*y4*sqrt(y2**2+y4**2)-g]

sol = desolve_odeint(f, y0, t, dvars=[y1, y2, y3, y4])

Y = np.array(sol)
    
arr = zip(Y[:,0],Y[:,2])

gr = line(arr)
gr.show(xmin=0, xmax=10, ymin=0, ymax=5, aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive
